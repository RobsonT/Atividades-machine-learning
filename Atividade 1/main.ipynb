# %% [markdown]
# # Ativida 1

# %% [markdown]
# ## Importação das bibliotecas

# %%
from regression import (RLA, RLGD, MLR, MLRGD, MLRSGD, Polynomial_regression as PR,
Regularized_multiple_linear_regression as RMLR)
from metrics import Metrics
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ## Leitura do Boston House Price Dataset

# %%
data = np.loadtxt("./data/housing.data", delimiter=",")
X = data[:,-2]
y = data[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.2)

# %% [markdown]
# ## Aplicação da regressão linear univariada e da regressão polinomial

# %%
model1 = RLA()
model2 = RLGD(learning_rate = 0.005, epochs=1000)
model3 = PR(degree = 2)
model4 = PR(degree = 3)
metrics = Metrics()

# %%
model1.fit(X_train, y_train)
y_train_predict = model1.predict(X_train)
y_test_predict = model1.predict(X_test)
print("Avaliação: ")
print("Coeficientes: {} e {} ".format(model1.b0, model1.b1))
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes: 33.27729521761091 e -35.662646758985055
# ------------------------Treino------------------------
# R2:  0.5537241723838973
# MSE:  39.48438782732911
# ------------------------Teste------------------------
# R2:  0.4877180129378291
# MSE:  34.80885001050415

# %%
model2.fit(X_train, y_train)
y_train_predict = model2.predict(X_train)
y_test_predict = model2.predict(X_test)
print("Avaliação: ")
print("Coeficientes: {} e {} ".format(model2.b0, model2.b1))
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes: 22.15037909443818 e 0.15065642540719817
# ------------------------Treino------------------------
# R2:  -0.007309481714501853
# MSE:  89.12200880477661
# ------------------------Teste------------------------
# R2:  -0.005999636776683026
# MSE:  68.35627906419332

# %%
model3.fit(X_train, y_train)
y_train_predict = model3.predict(X_train)
y_test_predict = model3.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ", model3.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [ 39.12836705 -79.9989197   57.75512806]
# ------------------------Treino------------------------
# R2:  0.6485708071008093
# MSE:  31.092803346304795
# ------------------------Teste------------------------
# R2:  0.5972816136801256
# MSE:  27.36415540642369

# %%
model4.fit(X_train, y_train)
y_train_predict = model4.predict(X_train)
y_test_predict = model4.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ",model4.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [  42.32729638 -121.36028221  179.03359812  -93.50987596]
# ------------------------Treino------------------------
# R2:  0.6636208264333927
# MSE:  29.761248367602917
# ------------------------Teste------------------------
# R2:  0.6254558085790165
# MSE:  25.44975796679015

# %% [markdown]
# ## Leitura de trab1_data.csv

# %%
data = np.loadtxt("./data/trab1_data.csv", skiprows=1, delimiter=",")
X = data[:,:-1]
y = data[:, -1]
X = (X - X.min()) / (X.max() - X.min())

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.2)

# %% [markdown]
# ## Aplicação da regressão linear multivariada

# %%
model5 = MLR()
model6 = MLRGD(learning_rate=0.001, epochs=1000, save_epoch_mse=True)
model7 = MLRSGD(learning_rate=0.001, epochs=20, save_epoch_mse=True)
model8 = RMLR(learning_rate=0.001, epochs=500, _lambda = 1, save_epoch_mse=False)
metrics = Metrics()

# %%
model5.fit(X_train, y_train)
y_train_predict = model5.predict(X_train)
y_test_predict = model5.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ",model5.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [ 3.06298171 -0.18627503 13.8305377  55.16627229 -1.21678916]
# ------------------------Treino------------------------
# R2:  0.9059228313557296
# MSE:  2.6314456770018335
# ------------------------Teste------------------------
# R2:  0.853210016260796
# MSE:  3.455329794482651

# %%
model6.fit(X_train, y_train)
y_train_predict = model6.predict(X_train)
y_test_predict = model6.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ",model6.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [6.9410598  2.26163815 4.68133674 0.98842979 1.73203071]
# ------------------------Treino------------------------
# R2:  -0.1415632944516878
# MSE:  31.930826995523283
# ------------------------Teste------------------------
# R2:  -0.31645662358380733
# MSE:  30.98843448811072

# %%
model7.fit(X_train, y_train)
y_train_predict = model7.predict(X_train)
y_test_predict = model7.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ",model7.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [7.89053083 2.38938955 8.21280523 1.83196864 1.937695  ]
# ------------------------Treino------------------------
# R2:  0.5159680856821249
# MSE:  13.538924553298267
# ------------------------Teste------------------------
# R2:  0.3476462185891439
# MSE:  15.355935057920027

# %%
model8.fit(X_train, y_train)
y_train_predict = model8.predict(X_train)
y_test_predict = model8.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ",model8.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [0.41153633 2.67610127 0.81775116 0.76242262]
# ------------------------Treino------------------------
# R2:  -1.4881841280688026
# MSE:  69.59734717515857
# ------------------------Teste------------------------
# R2:  -1.8324937003593407
# MSE:  66.67484814852611

# %%
plt.scatter(range(1,model6.epochs+1), model6.mse, color='black')
plt.plot(range(1,model6.epochs+1), model6.mse, color='blue')

# %%
plt.scatter(range(1,model7.epochs+1), model7.mse, color='black')
plt.plot(range(1,model7.epochs+1), model7.mse, color='blue')

# %%
mse = np.array([])
_lambda = 6

for l in range(1, _lambda):
    model = RMLR(learning_rate=0.01, epochs=100, _lambda = l, save_epoch_mse=True)
    model.fit(X_train, y_train)
    
    plt.plot(range(1,model.epochs+1), model.mse, color='blue')
    
    model1 = RMLR(learning_rate=0.01, epochs=100, _lambda = l, save_epoch_mse=True)
    model1.fit(X_test, y_test)
    
    plt.plot(range(1,model1.epochs+1), model1.mse, color='green')
    
    plt.show()
