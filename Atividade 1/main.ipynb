# %% [markdown]
# # Ativida 1

# %% [markdown]
# ## Importação das bibliotecas

# %%
from regression import (RLA, RLGD, MLR, MLRGD, MLRSGD, Polynomial_regression as PR,
Regularized_multiple_linear_regression as RMLR)
from metrics import Metrics
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ## Leitura do Boston House Price Dataset

# %%
data = np.loadtxt("./data/housing.data", delimiter=",")
X = data[:,-2]
y = data[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.2)

# %% [markdown]
# ## Aplicação da regressão linear univariada e da regressão polinomial

# %%
model1 = RLA()
model2 = RLGD(learning_rate = 0.009, epochs=1200)
model3 = PR(degree = 2)
model4 = PR(degree = 3)
metrics = Metrics()

# %%
model1.fit(X_train, y_train)
y_train_predict = model1.predict(X_train)
y_test_predict = model1.predict(X_test)
print("Avaliação: ")
print("Coeficientes: {} e {} ".format(model1.b0, model1.b1))
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes: 33.694970782019055 e -0.9003261643985221
# ------------------------Treino------------------------
# R2:  0.5590806721760522
# MSE:  33.91401906725609
# ------------------------Teste------------------------
# R2:  0.47556294207840855
# MSE:  57.465586822765225

# %%
model2.fit(X_train, y_train)
y_train_predict = model2.predict(X_train)
y_test_predict = model2.predict(X_test)
print("Avaliação: ")
print("Coeficientes: {} e {} ".format(model2.b0, model2.b1))
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes: 31.194271883842976 e -0.7533690827806191
# ------------------------Treino------------------------
# R2:  0.5395033074342742
# MSE:  35.41984355541369
# ------------------------Teste------------------------
# R2:  0.4146064183174438
# MSE:  64.14494396522595

# %%
model3.fit(X_train, y_train)
y_train_predict = model3.predict(X_train)
y_test_predict = model3.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ", model3.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [ 4.14164200e+01 -2.17138663e+00  3.95671945e-02]
# ------------------------Treino------------------------
# R2:  0.6526024171594371
# MSE:  26.720643675383982
# ------------------------Teste------------------------
# R2:  0.5841350351544226
# MSE:  45.56871770006137

# %%
model4.fit(X_train, y_train)
y_train_predict = model4.predict(X_train)
y_test_predict = model4.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ",model4.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [ 4.63997664e+01 -3.47945230e+00  1.28148560e-01 -1.66503991e-03]
# ------------------------Treino------------------------
# R2:  0.6664667266324891
# MSE:  25.654248019416816
# ------------------------Teste------------------------
# R2:  0.6099496297535183
# MSE:  42.74006399449008

# %% [markdown]
# O melhor modelo foi a regressão cúbica, isso significa que, provavelmete, a distribuição dos dados possui um formato
# mais próximo a uma equação de 3º grau, se ajustando melhor a esse modelo.

# %% [markdown]
# ## Leitura de trab1_data.csv

# %%
data = np.loadtxt("./data/trab1_data.csv", skiprows=1, delimiter=",")
X = data[:,1:-1]
y = data[:, -1]
X = (X - X.min()) / (X.max() - X.min())

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.2)

# %% [markdown]
# ## Aplicação da regressão linear multivariada

# %%
model5 = MLR()
model6 = MLRGD(learning_rate=0.99, epochs=1900, save_epoch_mse=True)
model7 = MLRSGD(learning_rate=0.009, epochs=1400, save_epoch_mse=True)
model8 = RMLR(learning_rate=0.09, epochs=1500, _lambda = 1, save_epoch_mse=False)
metrics = Metrics()

# %%
model5.fit(X_train, y_train)
y_train_predict = model5.predict(X_train)
y_test_predict = model5.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ",model5.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [ 3.0156334  13.45746943 54.88255677  0.22088941]
# ------------------------Treino------------------------
# R2:  0.8930485353274521
# MSE:  3.0295773334353684
# ------------------------Teste------------------------
# R2:  0.9166835629793925
# MSE:  1.8203725008195526

# %%
model6.fit(X_train, y_train)
y_train_predict = model6.predict(X_train)
y_test_predict = model6.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ",model6.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [ 3.04742478 13.46276419 53.77687761  0.73318304]
# ------------------------Treino------------------------
# R2:  0.8929455036959779
# MSE:  3.0324958750027657
# ------------------------Teste------------------------
# R2:  0.9152664327182197
# MSE:  1.8513352381828896

# %%
model7.fit(X_train, y_train)
y_train_predict = model7.predict(X_train)
y_test_predict = model7.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ",model7.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [ 3.04002313 13.46153148 54.03377762  0.61431776]
# ------------------------Treino------------------------
# R2:  0.892987810641651
# MSE:  3.031297460712224
# ------------------------Teste------------------------
# R2:  0.9156223981173388
# MSE:  1.8435577857740761

# %%
model8.fit(X_train, y_train)
y_train_predict = model8.predict(X_train)
y_test_predict = model8.predict(X_test)
print("Avaliação: ")
print("Coeficientes: ",model8.b)
print("------------------------Treino------------------------")
print("R2: ", metrics.R2(y_true=y_train, y_predict=y_train_predict))
print("MSE: ", metrics.MSE(y_train, y_train_predict))
print("------------------------Teste------------------------")
print("R2: ", metrics.R2(y_test, y_test_predict))
print("MSE: ", metrics.MSE(y_test, y_test_predict))
# Out:
# Avaliação:
# Coeficientes:  [ 0.354309    3.21656154 -3.16598602]
# ------------------------Treino------------------------
# R2:  0.04226706358115573
# MSE:  27.12937129512528
# ------------------------Teste------------------------
# R2:  0.03548094002867752
# MSE:  21.07368048940743

# %%
plt.scatter(range(1,model6.epochs+1), model6.mse, color='black')
plt.plot(range(1,model6.epochs+1), model6.mse, color='blue')

plt.title("Regressão linear usando gradiente descendente")
plt.xlabel("Época")
plt.ylabel("MSE")
plt.show()

# %%
plt.scatter(range(1,model7.epochs+1), model7.mse, color='black')
plt.plot(range(1,model7.epochs+1), model7.mse, color='blue')

plt.title("Regressão linear usando gradiente descendente estocastico")
plt.xlabel("Época")
plt.ylabel("MSE")
plt.show()

# %% [markdown]
# O metodo que utiliza gradiente descendente estocástico converge mais rapidamente, necessitando de um menor número de épocas e uma menor taxa de aprendizagem para alcanças valores de erro menores que o gradiente descendente.

# %%
mse = np.array([])
_lambda = 6

for l in range(1, _lambda):
    model = RMLR(learning_rate=0.09, epochs=1500, _lambda = l, save_epoch_mse=True)
    model.fit(X_train, y_train)
    
    plt.plot(range(1,model.epochs+1), model.mse, color='blue', label='Dados de treino')
    
    model1 = RMLR(learning_rate=0.09, epochs=1500, _lambda = l, save_epoch_mse=True)
    model1.fit(X_test, y_test)
    
    plt.plot(range(1,model1.epochs+1), model1.mse, color='green', label='Dados de teste')
    
    plt.title("Regressão linear regularizada com lambda = {}".format(l))
    plt.xlabel("Época")
    plt.ylabel("MSE")
    plt.legend()
    plt.show()

# %%
mse = np.array([])
mse1 = np.array([])
_lambda = 6

for l in range(1, _lambda):
    model = RMLR(learning_rate=0.09, epochs=1500, _lambda = l, save_epoch_mse=True)
    model.fit(X_train, y_train)
    
    mse = np.append(mse, metrics.MSE(y_train, model.predict(X_train)))
    mse1 = np.append(mse1, metrics.MSE(y_test, model.predict(X_test)))
    
plt.plot(range(1,_lambda), mse, color='blue', label='Dados de treino')
plt.plot(range(1,_lambda), mse1, color='green', label='Dados de teste')
    
plt.title("Regressão linear regularizada".format(l))
plt.xlabel("lambda")
plt.ylabel("MSE")
plt.legend()
plt.show()

# %% [markdown]
# O melhor é com lambda igual a 4, pois é onde obtemos os menores valores de MSE e também conseguimos uma maior aproximação entre a regressão de treino e teste.
