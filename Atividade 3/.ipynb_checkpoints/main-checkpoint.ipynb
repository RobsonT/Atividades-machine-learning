# %% [markdown]
# # Importação de bibliotecas

# %%
import numpy as np
from metrics import Metrics
from models import KNNClassifier, MLP
from sklearn.model_selection import train_test_split
from plots import Plots

# %% [markdown]
# # Leitura dos dados

# %%
data = np.loadtxt("./data1.txt", delimiter=",")
X = data[:, :-1]
y = data[:, -1]

# %% [markdown]
# # Apresentação dos resultados

# %%
def apply_classifier(classifier, clf_name):
    print('________________' + clf_name +'________________')
    Metrics().k_fold(X, y, 5, classifier)
    print('_____________Dados com fronteira de separação_____________')
    Plots().plot_boundaries(X, y, classifier)

# %%
k_list = range(1, 4)

for k in k_list:
    model1 = KNNClassifier(_k_neighbours=k)
    model1.classes_ = ['X1', 'X2']
    apply_classifier(model1, "KNN com {} vizinhos".format(k))
# Out:
# ________________KNN com 1 vizinhos________________
# ___________________________K-fold___________________________
# ___________________________Iteração 1___________________________
# Acurácia para dados de treino: 1.0
# Acurácia para dados de teste: 1.0
# ___________________________K-fold___________________________
# ___________________________Iteração 2___________________________
# Acurácia para dados de treino: 1.0
# Acurácia para dados de teste: 0.9
# ___________________________K-fold___________________________
# ___________________________Iteração 3___________________________
# Acurácia para dados de treino: 1.0
# Acurácia para dados de teste: 0.9
# ___________________________K-fold___________________________
# ___________________________Iteração 4___________________________
# Acurácia para dados de treino: 1.0
# Acurácia para dados de teste: 0.85
# ___________________________K-fold___________________________
# ___________________________Iteração 5___________________________
# Acurácia para dados de treino: 1.0
# Acurácia para dados de teste: 0.9
# Acurácia geral de treino: 1.0
# Acurácia geral de teste: 0.9099999999999999
# _____________Dados com fronteira de separação_____________
# ________________KNN com 2 vizinhos________________
# ___________________________K-fold___________________________
# ___________________________Iteração 1___________________________
# Acurácia para dados de treino: 1.0
# Acurácia para dados de teste: 0.85
# ___________________________K-fold___________________________
# ___________________________Iteração 2___________________________
# Acurácia para dados de treino: 1.0
# Acurácia para dados de teste: 0.9
# ___________________________K-fold___________________________
# ___________________________Iteração 3___________________________
# Acurácia para dados de treino: 1.0
# Acurácia para dados de teste: 0.9
# ___________________________K-fold___________________________
# ___________________________Iteração 4___________________________
# Acurácia para dados de treino: 1.0
# Acurácia para dados de teste: 0.95
# ___________________________K-fold___________________________
# ___________________________Iteração 5___________________________
# Acurácia para dados de treino: 1.0
# Acurácia para dados de teste: 0.95
# Acurácia geral de treino: 1.0
# Acurácia geral de teste: 0.9099999999999999
# _____________Dados com fronteira de separação_____________
# ________________KNN com 3 vizinhos________________
# ___________________________K-fold___________________________
# ___________________________Iteração 1___________________________
# Acurácia para dados de treino: 0.95
# Acurácia para dados de teste: 0.95
# ___________________________K-fold___________________________
# ___________________________Iteração 2___________________________
# Acurácia para dados de treino: 0.9375
# Acurácia para dados de teste: 0.9
# ___________________________K-fold___________________________
# ___________________________Iteração 3___________________________
# Acurácia para dados de treino: 0.9625
# Acurácia para dados de teste: 0.9
# ___________________________K-fold___________________________
# ___________________________Iteração 4___________________________
# Acurácia para dados de treino: 0.925
# Acurácia para dados de teste: 0.8
# ___________________________K-fold___________________________
# ___________________________Iteração 5___________________________
# Acurácia para dados de treino: 0.9375
# Acurácia para dados de teste: 0.9
# Acurácia geral de treino: 0.9425000000000001
# Acurácia geral de teste: 0.89
# _____________Dados com fronteira de separação_____________

# %%
layer_size_list = range(2, 5)

for layer_size in layer_size_list:
    model2 = MLP(_epochs=1500, _learning_rate=0.0001, _layer_size=layer_size)
    model2.classes_ = ['X1', 'X2']
    apply_classifier(model2, "MLP com {} unidades".format(layer_size))
# Out:
# ________________MLP com 2 unidades________________
# ___________________________K-fold___________________________
# ___________________________Iteração 1___________________________
# Acurácia para dados de treino: 0.6125
# Acurácia para dados de teste: 0.55
# ___________________________K-fold___________________________
# ___________________________Iteração 2___________________________
# Acurácia para dados de treino: 0.925
# Acurácia para dados de teste: 0.85
# ___________________________K-fold___________________________
# ___________________________Iteração 3___________________________
# Acurácia para dados de treino: 0.5875
# Acurácia para dados de teste: 0.65
# ___________________________K-fold___________________________
# ___________________________Iteração 4___________________________
# Acurácia para dados de treino: 0.375
# Acurácia para dados de teste: 0.5
# ___________________________K-fold___________________________
# ___________________________Iteração 5___________________________
# Acurácia para dados de treino: 0.4375
# Acurácia para dados de teste: 0.25
# Acurácia geral de treino: 0.5875
# Acurácia geral de teste: 0.5599999999999999
# _____________Dados com fronteira de separação_____________
# ________________MLP com 3 unidades________________
# ___________________________K-fold___________________________
# ___________________________Iteração 1___________________________
# Acurácia para dados de treino: 0.3875
# Acurácia para dados de teste: 0.45
# ___________________________K-fold___________________________
# ___________________________Iteração 2___________________________
# Acurácia para dados de treino: 0.4125
# Acurácia para dados de teste: 0.35
# ___________________________K-fold___________________________
# ___________________________Iteração 3___________________________
# Acurácia para dados de treino: 0.4
# Acurácia para dados de teste: 0.4
# ___________________________K-fold___________________________
# ___________________________Iteração 4___________________________
# Acurácia para dados de treino: 0.6
# Acurácia para dados de teste: 0.6
# ___________________________K-fold___________________________
# ___________________________Iteração 5___________________________
# Acurácia para dados de treino: 0.6
# Acurácia para dados de teste: 0.6
# Acurácia geral de treino: 0.4800000000000001
# Acurácia geral de teste: 0.4800000000000001
# _____________Dados com fronteira de separação_____________
# ________________MLP com 4 unidades________________
# ___________________________K-fold___________________________
# ___________________________Iteração 1___________________________
# Acurácia para dados de treino: 0.625
# Acurácia para dados de teste: 0.5
# ___________________________K-fold___________________________
# ___________________________Iteração 2___________________________
# Acurácia para dados de treino: 0.575
# Acurácia para dados de teste: 0.7
# ___________________________K-fold___________________________
# ___________________________Iteração 3___________________________
# Acurácia para dados de treino: 0.5625
# Acurácia para dados de teste: 0.75
# ___________________________K-fold___________________________
# ___________________________Iteração 4___________________________
# Acurácia para dados de treino: 0.6375
# Acurácia para dados de teste: 0.45
# ___________________________K-fold___________________________
# ___________________________Iteração 5___________________________
# Acurácia para dados de treino: 0.6
# Acurácia para dados de teste: 0.6
# Acurácia geral de treino: 0.6
# Acurácia geral de teste: 0.6
# _____________Dados com fronteira de separação_____________
